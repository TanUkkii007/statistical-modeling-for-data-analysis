# %%
# %matplotlib inline
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("data/data.csv",delimiter=",", skiprows=1, usecols=(1), dtype=np.int32)

# %%
data
# Out:
# array([2, 2, 4, 6, 4, 5, 2, 3, 1, 2, 0, 4, 3, 3, 3, 3, 4, 2, 7, 2, 4, 3,
#        3, 3, 4, 3, 7, 5, 3, 1, 7, 6, 4, 6, 5, 2, 4, 7, 2, 2, 6, 2, 4, 5,
#        4, 5, 1, 3, 2, 3], dtype=int32)

# %%
len(data)
# Out:
# 50

# %%
data.min()
# Out:
# 0

# %%
data.max()
# Out:
# 7

# %%
np.median(data)
# Out:
# 3.0

# %%
np.average(data)
# Out:
# 3.56

# %%
plt.hist(data, bins=8, histtype="stepfilled")
# Out:
# (array([ 1.,  3., 11., 12., 10.,  5.,  4.,  4.]),
#  array([0.   , 0.875, 1.75 , 2.625, 3.5  , 4.375, 5.25 , 6.125, 7.   ]),
#  <a list of 1 Patch objects>)

# %%
np.var(data)
# Out:
# 2.9264000000000006

# %%
np.std(data)
# Out:
# 1.710672382427448

# %%
np.sqrt(np.var(data))
# Out:
# 1.710672382427448

# %%
y = np.arange(9)
prob = stats.poisson.pmf(y, mu=3.56)

# %%
plt.plot(y, prob)

# %%
y = np.arange(20)
prob35 = stats.poisson.pmf(y, mu=3.5)
prob77 = stats.poisson.pmf(y, mu=7.7)
prob151 = stats.poisson.pmf(y, mu=15.1)

# %%
for p, l in zip([prob35, prob77, prob151], ["3.5", "7.7", "15.1"]):
    plt.plot(y, p, label=f"lambda={l}")
plt.legend()

# %% [markdown]
# ## 2.4

# %%
mu = np.arange(2.0, 5.0, 0.4)
N = mu.size
L = [np.sum(stats.poisson.logpmf(data, mu=l)) for l in mu]

# %%
fig = plt.figure(figsize=(16, 24))
x = np.arange(8)
for i, (l, mu) in enumerate(zip(L, list(mu))):
    ax1 = fig.add_subplot(N, 1, i + 1)
    ax1.hist(data, bins=8, histtype="stepfilled")
    y = stats.poisson.pmf(x, mu=mu)
    ax2 = ax1.twinx()
    ax2.plot(x, y, label=f"lambda = {mu:.1f}, L = {l:.1f}")
    ax2.legend()

# %% [markdown]
# ### 2.4.1

# %%
sample_average = []
for _ in range(3000):
    samples = stats.poisson.rvs(mu=3.5, size=50)
    sample_average.append(np.average(samples))

plt.hist(sample_average, bins=20, histtype="stepfilled")
# Out:
# (array([  3.,  11.,  16.,  38.,  56., 170., 250., 397., 446., 435., 418.,
#         308., 209., 109.,  91.,  25.,  10.,   4.,   3.,   1.]),
#  array([2.56 , 2.661, 2.762, 2.863, 2.964, 3.065, 3.166, 3.267, 3.368,
#         3.469, 3.57 , 3.671, 3.772, 3.873, 3.974, 4.075, 4.176, 4.277,
#         4.378, 4.479, 4.58 ]),
#  <a list of 1 Patch objects>)

# %%
sample_average = []
for _ in range(30):
    samples = stats.poisson.rvs(mu=3.5, size=50)
    sample_average.append(np.average(samples))

plt.hist(sample_average, bins=20, histtype="stepfilled")
# Out:
# (array([1., 0., 0., 2., 3., 2., 5., 2., 4., 3., 2., 1., 4., 0., 0., 0., 0.,
#         0., 0., 1.]),
#  array([3.02 , 3.085, 3.15 , 3.215, 3.28 , 3.345, 3.41 , 3.475, 3.54 ,
#         3.605, 3.67 , 3.735, 3.8  , 3.865, 3.93 , 3.995, 4.06 , 4.125,
#         4.19 , 4.255, 4.32 ]),
#  <a list of 1 Patch objects>)
