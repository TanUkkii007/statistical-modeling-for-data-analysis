# %%
load("data/data.RData")
write.csv(data, "data/data.csv")

# %%
data
# Out:
#  [1] 2 2 4 6 4 5 2 3 1 2 0 4 3 3 3 3 4 2 7 2 4 3 3 3 4 3 7 5 3 1 7 6 4 6 5 2 4 7
# [39] 2 2 6 2 4 5 4 5 1 3 2 3

# %%
length(data)
# Out:
# [1] 50

# %%
summary(data)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    0.00    2.00    3.00    3.56    4.75    7.00

# %%
table(data)
# Out:
# data
#  0  1  2  3  4  5  6  7
#  1  3 11 12 10  5  4  4

# %%
hist(data, breaks = seq(-0.5, 9.5, 1))
# Out:
# Plot with title “Histogram of data”

# %%
var(data)
# Out:
# [1] 2.986122

# %%
sd(data)
# Out:
# [1] 1.72804

# %%
sqrt(var(data))
# Out:
# [1] 1.72804

# %%
y <- 0:9
prob = dpois(y, lambda=3.56)

# %%
plot(y, prob, type="b", lty=2)
# Out:
# plot without title

# %%
y <- 0:20
prob35 = dpois(y, lambda=3.5)
prob77 = dpois(y, lambda=7.7)
prob151 = dpois(y, lambda=15.1)
plot(y, prob35, type="b", lty=2)
plot(y, prob77, type="b", lty=2)
plot(y, prob151, type="b", lty=2)
# Out:
# plot without title
# plot without title
# plot without title

# %%
logL <- function(m) sum(dpois(data, m, log=TRUE))
lambda <- seq(2,5,0.1)
plot(lambda, sapply(lambda, logL), type="l")
# Out:
# plot without title

# %%
lambda_hat = sum(data)/length(data)
lambda_hat
# Out:
# [1] 3.56
